# %%
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
from src.ScenarioSpace import ScenarioSpace
SS = ScenarioSpace(no_lsqr=True)
SS.load_output()
# Out:
# .
# . .
# . . .
# . .
# .
# .
# .
# . . . . . . . . .
# . .
# . . . . . . . .
# . . . . . . . . .
# . .
# . . .
# . .
# .
# . . .
# . .
# . . . . .
# . .
# . .
# .
# . . .
# . . . .
# . . .
# . . . . . . .
# . .
# . . .
# . . . .
# . .
# . . . .
# . . .
# .
# . .
# . .
# . . .
# . . .
# . .
# . .
# . .
# . . . . .
# . . .

# %%
print 'Levels of error: o, ^, v'
print 'LSQR: b, LS: g, CS: r, BI: c'
SS.plot_solver_comparison(sparse=False, caption='', model='P', max_NLPCP=200,
                          error_leq=0.1, error_leq2=0.3, error_leq3=0.5, b2n_leq=1.00, b2n_geq=0.95)
SS.plot_solver_comparison(sparse=False, caption='', model='P', max_NLPCP=200, 
                          error_leq=0.1, error_leq2=0.3, error_leq3=0.5, b2n_leq=0.95, b2n_geq=0.85)
SS.plot_solver_comparison(sparse=False, caption='', model='P', max_NLPCP=200,
                          error_leq=0.1, error_leq2=0.3, error_leq3=0.5, b2n_leq=0.85, b2n_geq=0.00)
SS.plot_solver_comparison(sparse=True, caption='', model='P', max_NLPCP=200,
                          error_leq=0.1, error_leq2=0.3, error_leq3=0.5, b2n_leq=1.00, b2n_geq=0.95)
SS.plot_solver_comparison(sparse=True, caption='', model='P', max_NLPCP=200, 
                          error_leq=0.1, error_leq2=0.3, error_leq3=0.5, b2n_leq=0.95, b2n_geq=0.85)
SS.plot_solver_comparison(sparse=True, caption='', model='P', max_NLPCP=200,
                          error_leq=0.1, error_leq2=0.3, error_leq3=0.5, b2n_leq=0.85, b2n_geq=0.00)
# Out:
# Levels of error: o, ^, v
# LSQR: b, LS: g, CS: r, BI: c
# [ 0.05] [u'BI'] [frozenset([('solver', u'BI')])] 1
# [ 0.41651452] [u'BI'] [frozenset([('solver', u'BI')])] 1
# [ 1.          1.33287836] [u'CS' u'BI'] [frozenset([('solver', u'CS')]), frozenset([('solver', u'BI')])] 2
# [ 0.03482397] [u'BI'] [frozenset([('solver', u'BI')])] 1
# [ 0.83221031] [u'BI'] [frozenset([('solver', u'BI')])] 1
# [ 1.01756225  1.42749598] [u'CS' u'BI'] [frozenset([('solver', u'CS')]), frozenset([('solver', u'BI')])] 2
# [ 1.07107026  1.61712728] [u'CS' u'BI'] [frozenset([('solver', u'CS')]), frozenset([('solver', u'BI')])] 2
# [ 1.15269411] [u'BI'] [frozenset([('solver', u'BI')])] 1
# [ 0.44346107] [u'BI'] [frozenset([('solver', u'BI')])] 1
# [ 1.22917436] [u'BI'] [frozenset([('solver', u'BI')])] 1
# [ 1.          0.92407093] [u'CS' u'BI'] [frozenset([('solver', u'CS')]), frozenset([('solver', u'BI')])] 2
# [ 0.55492021] [u'BI'] [frozenset([('solver', u'BI')])] 1
# ...

# %% [markdown]
# # Plot: network size (number of routes) vs speed (seconds)

# %%
SS.plot_size_vs_speed(error_leq=0.10,ylim=(-0.1,15))
SS.plot_size_vs_speed(error_leq=0.20,ylim=(-0.1,40))
SS.plot_size_vs_speed(error_leq=0.30,ylim=(-0.1,5))
SS.plot_size_vs_speed(error_leq=0.50,ylim=(-0.1,80))
SS.plot_size_vs_speed(error_leq=1.00,ylim=(-0.05,80))
# Out:
# [LS (*): 1816]
#  [BI (d): 3]
# [CS (x): 3]
# [LS (*): 2489]
#  [BI (d): 3]
# [CS (x): 3]
# [LS (*): 2890]
#  [BI (d): 4]
# [CS (x): 3]
# [LS (*): 3548]
#  [BI (d): 8]
# [CS (x): 4]
# [LS (*): 4297]
#  [BI (d): 16]
# [CS (x): 569]

# %% [markdown]
# # Plot: sparsity (nonzero routes / number of routes) vs route flow error (%)

# %%
SS.plot_sparsity_vs_error(error_leq=0.10,ylim=(-0.01,0.11),xlim=(0,0.7))
SS.plot_sparsity_vs_error(error_leq=1.00,ylim=(-0.01,1.05),xlim=(0,0.6),solvers=('BI',))
SS.plot_sparsity_vs_error(error_leq=1.00,ylim=(-0.01,1.05),xlim=(0,0.6),solvers=('CS',))
SS.plot_sparsity_vs_error(error_leq=1.00,ylim=(-0.01,1.05),xlim=(0,0.7),solvers=('LS',))
SS.plot_sparsity_vs_error(error_leq=1.00,ylim=(-0.01,1.05),xlim=(0,0.7),solvers=('LSQR',))
# Out:
# [LS (*): 1816]
#  [BI (d): 3]
# [CS (x): 3]
# [BI (*): 16]
# [CS (*): 569]
# [LS (*): 4297]
