# %%
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
from src.ScenarioSpace import ScenarioSpace
SS = ScenarioSpace(no_lsqr=True)
SS.load_output()
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# . . . . .
# . . .
# .
# .
# .
# . . . .
# . . . . .
# . .
# .
# .
# .
# .
# . .
# .
# .
# .
# . .
# . .
# . .
# . . .
# .
# .
# .
# . .
# . .
# .
# . . .
# .
# .
# . .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# . .
# .
# .
# . .
# . . . . . .
# .
# .
# .
# .
# . .
# .
# .
# .
# .
# .
# .
# . . .
# .
# .
# . . .
# .
# . .
# . .
# . .
# .
# . .
# .
# . .
# .
# .
# . .
# .
# .
# . . .
# . . .

# %% [markdown]
# ## [Dense] Plot: grid vs best solver (color); sliced by blocks-to-routes, markers indicate accuracy

# %%
print 'Levels of error: o, ^, v'
print 'LSQR: b, LS: g, CS: r, BI: c'
SS.plot_solver_comparison(sparse=False, caption='', model='P', error_leq=0.1,
                          error_leq2=1, error_leq3=100, b2n_leq=1.00, b2n_geq=0.00)
SS.plot_solver_comparison(sparse=False, caption='', model='P', error_leq=0.1,
                          error_leq2=1, error_leq3=100, b2n_leq=1.00, b2n_geq=0.95)
SS.plot_solver_comparison(sparse=False, caption='', model='P', error_leq=0.1,
                          error_leq2=1, error_leq3=100, b2n_leq=0.95, b2n_geq=0.85)
SS.plot_solver_comparison(sparse=False, caption='', model='P', error_leq=0.1,
                          error_leq2=1, error_leq3=100, b2n_leq=0.85, b2n_geq=0.00)
# Out:
# Levels of error: o, ^, v
# LSQR: b, LS: g, CS: r, BI: c
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 10 = [4, 6] | frozenset([('NLP', 8), ('nrow', 7), ('NCP', 42), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('NLP', 5), ('ncol', 4), ('NCP', 29), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 24), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 21 = [9, 12] | frozenset([('nrow', 4), ('NCP', 16), ('NLP', 3), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 16), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('ncol', 2), ('NLP', 0), ('nrow', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 8), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NCP', 35), ('nrow', 10), ('NLP', 0)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 35), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('NCP', 50), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 33 = [2, 31] | frozenset([('NCP', 345), ('NLP', 45), ('nrow', 10), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 38), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 49 = [7, 42] | frozenset([('nrow', 4), ('ncol', 8), ('NLP', 6), ('NCP', 132)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 6), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [2, 5] | frozenset([('NCP', 70), ('nrow', 10), ('ncol', 4), ('NLP', 12)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 29), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 25), ('NLP', 0), ('ncol', 4), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 19), ('NLP', 0), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [2, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 50), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 35), ('ncol', 4), ('nrow', 7), ('NLP', 0)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 40 = [3, 37] | frozenset([('NCP', 129), ('NLP', 5), ('ncol', 4), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('NLP', 26), ('NCP', 142), ('nrow', 10), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [1, 6] | frozenset([('NCP', 14), ('NLP', 0), ('ncol', 4), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 25), ('ncol', 2), ('NLP', 0), ('nrow', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 17), ('nrow', 4), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 58), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 11 = [2, 9] | frozenset([('nrow', 4), ('ncol', 6), ('NCP', 42), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NLP', 0), ('nrow', 10), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 10), ('NLP', 0), ('nrow', 1), ('NCP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 13 = [1, 12] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 4), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 4), ('nrow', 7), ('NLP', 12), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('NLP', 0), ('nrow', 1), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 46 = [9, 37] | frozenset([('nrow', 4), ('ncol', 6), ('NLP', 4), ('NCP', 124)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 6), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('nrow', 4), ('NLP', 0), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 17), ('nrow', 4), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NCP', 19), ('nrow', 10), ('NLP', 0)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [1, 6] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 4), ('NCP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [2, 2] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 6), ('NCP', 23)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('NLP', 13), ('ncol', 8), ('NCP', 77), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 39), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NLP', 0), ('nrow', 10), ('NCP', 23)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [3, 2] | frozenset([('NLP', 0), ('NCP', 24), ('nrow', 7), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 29 = [4, 25] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 157), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('ncol', 10), ('NLP', 23), ('nrow', 7), ('NCP', 124)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 6), ('NLP', 0), ('ncol', 10), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('nrow', 4), ('ncol', 10), ('NCP', 39), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('ncol', 4), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 12 = [1, 11] | frozenset([('NCP', 9), ('nrow', 4), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 14 = [5, 9] | frozenset([('NLP', 5), ('ncol', 4), ('nrow', 7), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('nrow', 4), ('NCP', 8), ('NLP', 1), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 10), ('NLP', 35), ('NCP', 194), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 35), ('nrow', 10), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('NLP', 13), ('nrow', 7), ('NCP', 74), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [2, 3] | frozenset([('NCP', 25), ('ncol', 2), ('nrow', 7), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 11 = [1, 10] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 16), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 39), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('NCP', 5), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 51), ('NLP', 0), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 7), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [2, 2] | frozenset([('NLP', 0), ('ncol', 4), ('nrow', 7), ('NCP', 39)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 42), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 4), ('nrow', 7), ('NCP', 50), ('NLP', 9)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 14 = [1, 13] | frozenset([('NLP', 10), ('NCP', 158), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [2, 4] | frozenset([('NCP', 57), ('NLP', 10), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 43 = [7, 36] | frozenset([('nrow', 4), ('NLP', 3), ('ncol', 4), ('NCP', 116)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [2, 4] | frozenset([('ncol', 8), ('nrow', 10), ('NLP', 36), ('NCP', 196)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 35 = [5, 30] | frozenset([('nrow', 4), ('ncol', 2), ('NLP', 1), ('NCP', 108)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('nrow', 4), ('NCP', 32), ('NLP', 6), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [2, 5] | frozenset([('nrow', 10), ('NCP', 59), ('NLP', 11), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 19 = [7, 12] | frozenset([('nrow', 4), ('NCP', 24), ('ncol', 6), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [2, 5] | frozenset([('ncol', 8), ('nrow', 10), ('NCP', 79), ('NLP', 15)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 25), ('nrow', 4), ('NLP', 0), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 57), ('nrow', 4), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [2, 2] | frozenset([('NCP', 19), ('nrow', 10), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('NCP', 70), ('ncol', 10), ('NLP', 12), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 19), ('ncol', 4), ('NLP', 0)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 2), ('NCP', 35), ('nrow', 10), ('NLP', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 8), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 10), ('NLP', 0), ('NCP', 16), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [1, 6] | frozenset([('nrow', 10), ('NLP', 19), ('NCP', 106), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 38), ('NLP', 0), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('NCP', 8), ('nrow', 1), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('ncol', 4), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 24), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 12 = [4, 8] | frozenset([('NLP', 2), ('NCP', 14), ('nrow', 7), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 0), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 34 = [4, 30] | frozenset([('NCP', 142), ('nrow', 4), ('ncol', 6), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('NLP', 10), ('nrow', 7), ('NCP', 55), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 7), ('NLP', 0), ('NCP', 5), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 10), ('NLP', 0), ('NCP', 8), ('nrow', 1)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [3, 3] | frozenset([('NCP', 137), ('nrow', 7), ('NLP', 25), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [2, 7] | frozenset([('NLP', 13), ('NCP', 69), ('nrow', 7), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('nrow', 10), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('nrow', 10), ('ncol', 2), ('NCP', 19), ('NLP', 3)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 23), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 10 = [3, 7] | frozenset([('nrow', 10), ('ncol', 4), ('NCP', 39), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 58), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('NLP', 0), ('ncol', 4), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 8), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [3, 3] | frozenset([('NLP', 5), ('ncol', 4), ('NCP', 29), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [2, 4] | frozenset([('ncol', 8), ('nrow', 10), ('NLP', 36), ('NCP', 196)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [2, 3] | frozenset([('nrow', 4), ('NCP', 16), ('NLP', 3), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [2, 5] | frozenset([('NCP', 70), ('ncol', 10), ('NLP', 12), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NCP', 35), ('nrow', 10), ('NLP', 0)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 33 = [2, 31] | frozenset([('NCP', 345), ('NLP', 45), ('nrow', 10), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [2, 5] | frozenset([('NCP', 70), ('nrow', 10), ('ncol', 4), ('NLP', 12)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 29 = [2, 27] | frozenset([('NCP', 129), ('NLP', 5), ('ncol', 4), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('nrow', 4), ('ncol', 6), ('NCP', 42), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('nrow', 4), ('ncol', 6), ('NLP', 4), ('NCP', 124)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('NLP', 13), ('ncol', 8), ('NCP', 77), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 24 = [4, 20] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 157), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('ncol', 10), ('NLP', 23), ('nrow', 7), ('NCP', 124)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('nrow', 4), ('NCP', 8), ('NLP', 1), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 10), ('NLP', 35), ('NCP', 194), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NLP', 13), ('nrow', 7), ('NCP', 74), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('NCP', 25), ('ncol', 2), ('nrow', 7), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [2, 5] | frozenset([('NLP', 26), ('NCP', 142), ('nrow', 10), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 51), ('NLP', 0), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 12 = [1, 11] | frozenset([('NLP', 10), ('NCP', 158), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [2, 4] | frozenset([('NCP', 57), ('NLP', 10), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 10 = [2, 8] | frozenset([('nrow', 4), ('NLP', 3), ('ncol', 4), ('NCP', 116)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('nrow', 4), ('ncol', 2), ('NLP', 1), ('NCP', 108)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 24), ('ncol', 6), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 4), ('nrow', 7), ('NLP', 12), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [1, 6] | frozenset([('nrow', 10), ('NLP', 19), ('NCP', 106), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 58), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 27 = [3, 24] | frozenset([('NCP', 142), ('nrow', 4), ('ncol', 6), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [3, 3] | frozenset([('NCP', 137), ('nrow', 7), ('NLP', 25), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 10 = [4, 6] | frozenset([('nrow', 4), ('NCP', 16), ('NLP', 3), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('NLP', 8), ('nrow', 7), ('NCP', 42), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 36 = [7, 29] | frozenset([('nrow', 4), ('ncol', 8), ('NLP', 6), ('NCP', 132)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('ncol', 4), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('NLP', 5), ('ncol', 4), ('nrow', 7), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 10 = [1, 9] | frozenset([('NCP', 129), ('NLP', 5), ('ncol', 4), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('nrow', 10), ('ncol', 2), ('NCP', 19), ('NLP', 3)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 24 = [6, 18] | frozenset([('nrow', 4), ('ncol', 6), ('NLP', 4), ('NCP', 124)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [1, 6] | frozenset([('NLP', 10), ('nrow', 7), ('NCP', 55), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [1, 5] | frozenset([('ncol', 8), ('nrow', 10), ('NCP', 79), ('NLP', 15)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('NCP', 25), ('ncol', 2), ('nrow', 7), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 18 = [4, 14] | frozenset([('nrow', 4), ('NLP', 3), ('ncol', 4), ('NCP', 116)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [3, 3] | frozenset([('nrow', 4), ('NCP', 32), ('NLP', 6), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 12 = [5, 7] | frozenset([('nrow', 4), ('NCP', 24), ('ncol', 6), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 4), ('nrow', 7), ('NCP', 50), ('NLP', 9)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 19), ('ncol', 4), ('NLP', 0)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NLP', 2), ('NCP', 14), ('nrow', 7), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [2, 4] | frozenset([('nrow', 10), ('NCP', 59), ('NLP', 11), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [1, 6] | frozenset([('NCP', 142), ('nrow', 4), ('ncol', 6), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('NLP', 13), ('NCP', 69), ('nrow', 7), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [2, 2] | frozenset([('nrow', 10), ('ncol', 4), ('NCP', 39), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 24), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [3, 3] | frozenset([('nrow', 4), ('NCP', 16), ('NLP', 3), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 16), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 0), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('NCP', 8), ('nrow', 1), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 24), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 38), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 6), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [2, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 50), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 29), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 25), ('NLP', 0), ('ncol', 4), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 17), ('nrow', 4), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('NLP', 5), ('ncol', 4), ('nrow', 7), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 10), ('ncol', 2), ('NCP', 19), ('NLP', 3)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [1, 6] | frozenset([('NCP', 14), ('NLP', 0), ('ncol', 4), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 25), ('ncol', 2), ('NLP', 0), ('nrow', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NLP', 0), ('nrow', 10), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 10), ('NLP', 0), ('nrow', 1), ('NCP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 13 = [1, 12] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 4), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('NLP', 0), ('nrow', 1), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('NCP', 50), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 6), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('nrow', 4), ('NLP', 0), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NCP', 19), ('nrow', 10), ('NLP', 0)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [1, 6] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 4), ('NCP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 25), ('nrow', 4), ('NLP', 0), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [2, 2] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 6), ('NCP', 23)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 39), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NLP', 0), ('nrow', 10), ('NCP', 23)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 6), ('NLP', 0), ('ncol', 10), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('ncol', 4), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 42), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [2, 2] | frozenset([('NLP', 0), ('ncol', 4), ('nrow', 7), ('NCP', 39)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 12 = [1, 11] | frozenset([('NCP', 9), ('nrow', 4), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('nrow', 4), ('NCP', 8), ('NLP', 1), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 17), ('nrow', 4), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 35), ('nrow', 10), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 11 = [1, 10] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 16), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 39), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('NCP', 5), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 35), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 15 = [1, 14] | frozenset([('nrow', 4), ('NLP', 3), ('ncol', 4), ('NCP', 116)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 35), ('ncol', 4), ('nrow', 7), ('NLP', 0)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 25 = [4, 21] | frozenset([('nrow', 4), ('ncol', 2), ('NLP', 1), ('NCP', 108)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 4), ('NCP', 24), ('ncol', 6), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 57), ('nrow', 4), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [2, 2] | frozenset([('NCP', 19), ('nrow', 10), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 2), ('NCP', 35), ('nrow', 10), ('NLP', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 8), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 8), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 10), ('NLP', 0), ('NCP', 16), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 38), ('NLP', 0), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('ncol', 2), ('NLP', 0), ('nrow', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('nrow', 4), ('ncol', 10), ('NCP', 39), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [3, 4] | frozenset([('NLP', 2), ('NCP', 14), ('nrow', 7), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 19), ('NLP', 0), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [3, 2] | frozenset([('NLP', 0), ('NCP', 24), ('nrow', 7), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 7), ('NLP', 0), ('NCP', 5), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 10), ('NLP', 0), ('NCP', 8), ('nrow', 1)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('nrow', 10), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 23), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 10), ('ncol', 4), ('NCP', 39), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 7), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 58), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('NLP', 0), ('ncol', 4), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 8), ('ncol', 6)])

# %% [markdown]
# ## [Sparse] Plot: grid vs best solver (color); sliced by blocks-to-routes, markers indicate accuracy

# %%
SS.plot_solver_comparison(sparse=True, caption='', model='P', error_leq=0.1,
                          error_leq2=1, error_leq3=100, b2n_leq=1.00, b2n_geq=0.00)
SS.plot_solver_comparison(sparse=True, caption='', model='P', error_leq=0.1,
                          error_leq2=1, error_leq3=100, b2n_leq=1.00, b2n_geq=0.95)
SS.plot_solver_comparison(sparse=True, caption='', model='P', error_leq=0.1,
                          error_leq2=1, error_leq3=100, b2n_leq=0.95, b2n_geq=0.85)
SS.plot_solver_comparison(sparse=True, caption='', model='P', error_leq=0.1,
                          error_leq2=1, error_leq3=100, b2n_leq=0.85, b2n_geq=0.00)
# Out:
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 109), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('ncol', 4), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 97), ('nrow', 10), ('NLP', 17), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 5), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('ncol', 4), ('nrow', 7), ('NCP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 29), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('ncol', 10), ('NLP', 0), ('nrow', 1)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [2, 7] | frozenset([('NLP', 13), ('ncol', 8), ('NCP', 77), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('NLP', 18), ('NCP', 99), ('nrow', 7), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [2, 3] | frozenset([('ncol', 2), ('NLP', 0), ('nrow', 10), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('NCP', 70), ('ncol', 10), ('NLP', 12), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [1, 8] | frozenset([('NLP', 10), ('nrow', 7), ('NCP', 55), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 5), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 24), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 11 = [3, 8] | frozenset([('nrow', 4), ('NCP', 8), ('NLP', 1), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('ncol', 8), ('nrow', 10), ('NCP', 79), ('NLP', 15)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [3, 4] | frozenset([('NCP', 25), ('ncol', 2), ('nrow', 7), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 8), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 66 = [4, 62] | frozenset([('nrow', 4), ('NLP', 3), ('ncol', 4), ('NCP', 116)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [3, 6] | frozenset([('ncol', 4), ('nrow', 7), ('NLP', 12), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 1), ('ncol', 4), ('NCP', 5), ('NLP', 1)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [1, 5] | frozenset([('NLP', 18), ('NCP', 102), ('nrow', 7), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 18), ('ncol', 10), ('nrow', 10), ('NCP', 98)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [4, 5] | frozenset([('nrow', 10), ('NCP', 59), ('NLP', 11), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 2), ('nrow', 10), ('NCP', 47), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 10 = [3, 7] | frozenset([('NLP', 13), ('NCP', 69), ('nrow', 7), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 25), ('nrow', 4), ('NLP', 0), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NLP', 0), ('nrow', 7), ('NCP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 13 = [2, 11] | frozenset([('nrow', 4), ('ncol', 6), ('NCP', 42), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('ncol', 10), ('NCP', 171), ('nrow', 7), ('NLP', 31)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 22 = [7, 15] | frozenset([('nrow', 4), ('NCP', 16), ('NLP', 3), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('NCP', 38), ('ncol', 4), ('NLP', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 4), ('ncol', 10), ('NCP', 39), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NLP', 8), ('nrow', 7), ('NCP', 42), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 24), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('ncol', 4), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NCP', 70), ('nrow', 10), ('ncol', 4), ('NLP', 12)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 106 = [3, 103] | frozenset([('NCP', 129), ('NLP', 5), ('ncol', 4), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('NCP', 17), ('NLP', 2), ('nrow', 1), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('ncol', 10), ('nrow', 7), ('NCP', 226), ('NLP', 41)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [1, 8] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 4), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 10), ('NLP', 0), ('NCP', 8), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 15 = [7, 8] | frozenset([('NLP', 5), ('ncol', 4), ('nrow', 7), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [2, 5] | frozenset([('ncol', 10), ('NLP', 23), ('nrow', 7), ('NCP', 124)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 7), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 11 = [4, 7] | frozenset([('NLP', 13), ('nrow', 7), ('NCP', 74), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 35), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 36 = [6, 30] | frozenset([('NLP', 10), ('NCP', 158), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('NLP', 26), ('nrow', 10), ('NCP', 146), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 51 = [7, 44] | frozenset([('nrow', 4), ('ncol', 2), ('NLP', 1), ('NCP', 108)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('ncol', 8), ('NCP', 259), ('nrow', 10), ('NLP', 47)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('ncol', 4), ('nrow', 7), ('NCP', 50), ('NLP', 9)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [1, 5] | frozenset([('NCP', 137), ('nrow', 7), ('NLP', 25), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [3, 4] | frozenset([('NCP', 6), ('nrow', 1), ('NLP', 1), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [2, 3] | frozenset([('ncol', 8), ('nrow', 10), ('NLP', 36), ('NCP', 196)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('ncol', 4), ('nrow', 7), ('NCP', 39)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 2), ('NCP', 14), ('nrow', 7), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 70 = [11, 59] | frozenset([('NCP', 345), ('NLP', 45), ('nrow', 10), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 37 = [1, 36] | frozenset([('nrow', 4), ('ncol', 8), ('NLP', 6), ('NCP', 132)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 16 = [5, 11] | frozenset([('NLP', 5), ('ncol', 4), ('NCP', 29), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 70), ('NLP', 0), ('ncol', 10), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 26 = [1, 25] | frozenset([('NLP', 2), ('nrow', 4), ('NCP', 114), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('nrow', 1), ('NCP', 8), ('NLP', 1), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 101), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 42), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 51), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 35), ('nrow', 10), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [3, 6] | frozenset([('NCP', 9), ('ncol', 10), ('nrow', 1), ('NLP', 1)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 29), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 4), ('NCP', 128), ('NLP', 22), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 19), ('nrow', 10), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('ncol', 2), ('NCP', 35), ('nrow', 10), ('NLP', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 103), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 17), ('ncol', 2), ('NLP', 0), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 6), ('NLP', 0), ('ncol', 4), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('nrow', 10), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 23), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [3, 6] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 58), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('NLP', 24), ('nrow', 7), ('ncol', 6), ('NCP', 135)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 18 = [3, 15] | frozenset([('NCP', 177), ('NLP', 13), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 10), ('NLP', 0), ('NCP', 24), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 6), ('NLP', 0), ('nrow', 1), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NLP', 0), ('NCP', 8), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 10), ('ncol', 2), ('NCP', 19), ('NLP', 3)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 34 = [3, 31] | frozenset([('nrow', 4), ('ncol', 6), ('NLP', 4), ('NCP', 124)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 18), ('nrow', 4), ('NCP', 103), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 50 = [4, 46] | frozenset([('NCP', 142), ('nrow', 4), ('ncol', 6), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 47 = [8, 39] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 157), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 38 = [5, 33] | frozenset([('NCP', 177), ('NLP', 13), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [4, 5] | frozenset([('NLP', 26), ('NCP', 142), ('nrow', 10), ('ncol', 8)])
# [2=array([u'CS', u'BI'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 77), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('NCP', 57), ('NLP', 10), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [3, 5] | frozenset([('NLP', 2), ('NCP', 14), ('ncol', 2), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 19), ('NLP', 0), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 11 = [4, 7] | frozenset([('nrow', 4), ('NCP', 24), ('ncol', 6), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 7), ('NLP', 0), ('ncol', 4), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('ncol', 10), ('nrow', 1), ('NLP', 3), ('NCP', 23)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 8), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [2, 4] | frozenset([('nrow', 10), ('NLP', 19), ('NCP', 106), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('nrow', 7), ('ncol', 6), ('NLP', 36), ('NCP', 204)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('NCP', 50), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('nrow', 10), ('ncol', 4), ('NCP', 39), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('nrow', 4), ('NLP', 0), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 70), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 58), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 109), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 8), ('nrow', 10), ('NLP', 36), ('NCP', 196)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 47 = [8, 39] | frozenset([('NCP', 345), ('NLP', 45), ('nrow', 10), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('NLP', 24), ('nrow', 7), ('ncol', 6), ('NCP', 135)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 19 = [1, 18] | frozenset([('NCP', 129), ('NLP', 5), ('ncol', 4), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('ncol', 10), ('nrow', 7), ('NCP', 226), ('NLP', 41)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('NLP', 18), ('nrow', 4), ('NCP', 103), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('NLP', 13), ('ncol', 8), ('NCP', 77), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [2, 7] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 157), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 101), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 21 = [3, 18] | frozenset([('NCP', 177), ('NLP', 13), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 128), ('NLP', 22), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 19 = [3, 16] | frozenset([('NLP', 10), ('NCP', 158), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('ncol', 8), ('NCP', 259), ('nrow', 10), ('NLP', 47)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('NLP', 5), ('ncol', 4), ('NCP', 29), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 2), ('NCP', 35), ('nrow', 10), ('NLP', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 103), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('ncol', 4), ('nrow', 7), ('NLP', 12), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('nrow', 7), ('ncol', 6), ('NLP', 36), ('NCP', 204)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 11 = [1, 10] | frozenset([('NCP', 142), ('nrow', 4), ('ncol', 6), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NCP', 137), ('nrow', 7), ('NLP', 25), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 58), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 8), ('nrow', 10), ('NLP', 36), ('NCP', 196)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('nrow', 4), ('NCP', 16), ('NLP', 3), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('ncol', 4), ('nrow', 7), ('NCP', 39)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 10 = [3, 7] | frozenset([('NCP', 177), ('NLP', 13), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 13), ('nrow', 7), ('NCP', 74), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('NCP', 38), ('ncol', 4), ('NLP', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 22 = [3, 19] | frozenset([('NCP', 345), ('NLP', 45), ('nrow', 10), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('ncol', 4), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 54 = [2, 52] | frozenset([('NCP', 129), ('NLP', 5), ('ncol', 4), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('NLP', 18), ('NCP', 99), ('nrow', 7), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [2, 3] | frozenset([('NLP', 5), ('ncol', 4), ('NCP', 29), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('NLP', 2), ('nrow', 4), ('NCP', 114), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 15 = [4, 11] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 157), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [1, 5] | frozenset([('ncol', 10), ('NLP', 23), ('nrow', 7), ('NCP', 124)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [2, 3] | frozenset([('NCP', 17), ('NLP', 2), ('nrow', 1), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 12 = [1, 11] | frozenset([('NCP', 177), ('NLP', 13), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('NCP', 25), ('ncol', 2), ('nrow', 7), ('NLP', 4)])
# [2=array([u'CS', u'BI'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 77), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 13 = [2, 11] | frozenset([('NLP', 10), ('NCP', 158), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('NCP', 57), ('NLP', 10), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('NLP', 2), ('NCP', 14), ('ncol', 2), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [1, 5] | frozenset([('nrow', 4), ('ncol', 2), ('NLP', 1), ('NCP', 108)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [2, 1] | frozenset([('ncol', 10), ('nrow', 1), ('NLP', 3), ('NCP', 23)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [3, 3] | frozenset([('ncol', 4), ('nrow', 7), ('NCP', 50), ('NLP', 9)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 4), ('nrow', 7), ('NLP', 12), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [2, 3] | frozenset([('nrow', 10), ('NLP', 19), ('NCP', 106), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 2), ('nrow', 10), ('NCP', 47), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 70), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [2, 3] | frozenset([('nrow', 4), ('ncol', 6), ('NCP', 42), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('ncol', 4), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 24), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 58), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 7 = [3, 4] | frozenset([('NCP', 6), ('nrow', 1), ('NLP', 1), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 6), ('NLP', 0), ('ncol', 4), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 20 = [6, 14] | frozenset([('nrow', 4), ('NCP', 16), ('NLP', 3), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('NCP', 70), ('nrow', 10), ('ncol', 4), ('NLP', 12)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('ncol', 8), ('nrow', 10), ('NCP', 79), ('NLP', 15)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 10), ('NLP', 0), ('NCP', 24), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 19), ('NLP', 0), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('ncol', 4), ('nrow', 7), ('NCP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 0), ('nrow', 10), ('NCP', 50), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NLP', 0), ('NCP', 8), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 36 = [1, 35] | frozenset([('nrow', 4), ('ncol', 8), ('NLP', 6), ('NCP', 132)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 29), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('ncol', 10), ('NLP', 0), ('nrow', 1)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 18), ('ncol', 10), ('nrow', 10), ('NCP', 98)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [2, 3] | frozenset([('ncol', 2), ('NLP', 0), ('nrow', 10), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 70), ('NLP', 0), ('ncol', 10), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [1, 8] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 4), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 2 = [1, 1] | frozenset([('ncol', 4), ('nrow', 7), ('NLP', 12), ('NCP', 68)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 10), ('NLP', 0), ('NCP', 8), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 32 = [3, 29] | frozenset([('nrow', 4), ('ncol', 6), ('NLP', 4), ('NCP', 124)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [2, 6] | frozenset([('nrow', 1), ('NCP', 8), ('NLP', 1), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 19), ('nrow', 10), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 23 = [2, 21] | frozenset([('NLP', 10), ('nrow', 4), ('NCP', 157), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NLP', 18), ('NCP', 99), ('nrow', 7), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 42), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('nrow', 10), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('NCP', 177), ('NLP', 13), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 15 = [7, 8] | frozenset([('NLP', 5), ('ncol', 4), ('nrow', 7), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 24), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 10 = [2, 8] | frozenset([('nrow', 4), ('NCP', 8), ('NLP', 1), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 7), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 51), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 5), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 35), ('nrow', 10), ('NLP', 0), ('ncol', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [3, 3] | frozenset([('NLP', 13), ('nrow', 7), ('NCP', 74), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 25), ('ncol', 2), ('nrow', 7), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NCP', 35), ('NLP', 0), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 5), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 29), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NLP', 10), ('NCP', 158), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 57), ('NLP', 10), ('ncol', 8), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 61 = [4, 57] | frozenset([('nrow', 4), ('NLP', 3), ('ncol', 4), ('NCP', 116)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 6 = [2, 4] | frozenset([('NLP', 2), ('NCP', 14), ('ncol', 2), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 44 = [6, 38] | frozenset([('nrow', 4), ('ncol', 2), ('NLP', 1), ('NCP', 108)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 11 = [4, 7] | frozenset([('nrow', 4), ('NCP', 24), ('ncol', 6), ('NLP', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 8 = [1, 7] | frozenset([('NLP', 5), ('ncol', 4), ('NCP', 29), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NLP', 8), ('nrow', 7), ('NCP', 42), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [3, 6] | frozenset([('NCP', 9), ('ncol', 10), ('nrow', 1), ('NLP', 1)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 5 = [1, 4] | frozenset([('nrow', 10), ('ncol', 4), ('NCP', 39), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 70), ('ncol', 10), ('NLP', 12), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 10), ('ncol', 2), ('NCP', 19), ('NLP', 3)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 17), ('ncol', 2), ('NLP', 0), ('nrow', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('ncol', 8), ('NCP', 28)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 1), ('ncol', 4), ('NCP', 5), ('NLP', 1)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('nrow', 4), ('ncol', 10), ('NCP', 39), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NLP', 2), ('NCP', 14), ('nrow', 7), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 24 = [3, 21] | frozenset([('NCP', 142), ('nrow', 4), ('ncol', 6), ('NLP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [1, 8] | frozenset([('NLP', 10), ('nrow', 7), ('NCP', 55), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 10 = [3, 7] | frozenset([('NLP', 13), ('NCP', 69), ('nrow', 7), ('ncol', 10)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('nrow', 10), ('ncol', 2)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 23), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 25), ('nrow', 4), ('NLP', 0), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 7), ('NLP', 0), ('ncol', 4), ('NCP', 5)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 9 = [4, 5] | frozenset([('nrow', 10), ('NCP', 59), ('NLP', 11), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 6), ('NLP', 0), ('nrow', 1), ('ncol', 8)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 4 = [1, 3] | frozenset([('NCP', 38), ('ncol', 4), ('NLP', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('ncol', 2), ('NLP', 0), ('nrow', 7), ('NCP', 7)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 9), ('nrow', 4), ('NLP', 0), ('ncol', 6)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('NCP', 14), ('NLP', 0), ('ncol', 6), ('nrow', 4)])
# [2=array([u'CS', u'LS'],
#       dtype='<U2')], 3 = [1, 2] | frozenset([('nrow', 4), ('NLP', 0), ('NCP', 8), ('ncol', 6)])

# %% [markdown]
# # Plot: network size (number of routes) vs speed (seconds)

# %%
SS.plot_size_vs_speed(error_leq=0.10,ylim=(-0.1,1000))
SS.plot_size_vs_speed(error_leq=0.30,ylim=(-0.1,600),solvers=('LS',))
SS.plot_size_vs_speed(error_leq=0.30,ylim=(-0.1,5),solvers=('CS',))
SS.plot_size_vs_speed(error_leq=0.30,ylim=(-0.1,2000),solvers=('BI',))
SS.plot_size_vs_speed(error_leq=10.00,ylim=(-0.1,600),solvers=('LS',))
SS.plot_size_vs_speed(error_leq=10.00,ylim=(-0.1,60),solvers=('CS',))
SS.plot_size_vs_speed(error_leq=10.00,ylim=(-0.1,2000),solvers=('BI',))
# Out:
# [LS (*): 1846]
#  [BI (d): 23]
# [CS (x): 5]
# [LS (*): 2936]
# [CS (*): 5]
# [BI (*): 58]
# [LS (*): 5394]
# [CS (*): 461]
# [BI (*): 369]

# %%
SS.plot_size_vs_speed(error_leq=1.00,ylim=(-0.1,700),solvers=('LS',),color_axis='error')
SS.plot_size_vs_speed(error_leq=10.00,ylim=(-0.1,60),solvers=('CS',),color_axis='error')
SS.plot_size_vs_speed(error_leq=1.00,ylim=(-0.1,2000),solvers=('BI',),color_axis='error')
# Out:
# [LS (*): 4450]
# [CS (*): 461]
# [BI (*): 140]

# %% [markdown]
# # Plot: sparsity (nonzero routes / number of routes) vs route flow error (%)

# %%
SS.plot_sparsity_vs_error(error_leq=0.10,ylim=(-0.01,0.11),xlim=(0,0.7))
SS.plot_sparsity_vs_error(error_leq=2.0,ylim=(-0.01,2.05),xlim=(0,0.6),solvers=('BI',))
SS.plot_sparsity_vs_error(error_leq=2.0,ylim=(-0.01,2.05),xlim=(0,0.6),solvers=('CS',))
SS.plot_sparsity_vs_error(error_leq=10.0,ylim=(-0.01,10.05),xlim=(0,0.7),solvers=('LS',))
# SS.plot_sparsity_vs_error(error_leq=10.0,ylim=(-0.01,10.05),xlim=(0,0.7),solvers=('LSQR',))
# Out:
# [LS (*): 2342]
#  [BI (d): 23]
# [CS (x): 5]
# [BI (*): 369]
# [CS (*): 461]
# [LS (*): 6533]
