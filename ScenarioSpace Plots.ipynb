# %%
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
from src.ScenarioSpace import ScenarioSpace
SS = ScenarioSpace(no_lsqr=True)
SS.load_output()
SS.generate_statistics(error=10)
# Out:
# .
# . .
# . .
# .
# . .
# .
# .
# .
# . . . . . .
# . .
# .
# .
# .
# . . . . . . . .
# .
# .
# .
# . . . . . . .
# . .
# . .
# . . .
# .
# .
# .
# . . .
# . .
# . . .
# .
# .
# .
# .
# .
# . .
# .
# . .
# . . . .
# . . .
# . . . . . .
# . .
# . . .
# . . .
# .
# . .
# . . .
# .
# . .
# . . .
# . .
# . .
# . . .
# . .
# . . .
# .
# .
# . .
# . .
# . . . . . .
# Number of (valid) scenarios: 7424
# Number with error <=10: 7411
# Of those we have
# [({'sparse': False}, 3143), ({'sparse': True}, 4268)]
# Of those we have[({'solver': u'BI', 'sparse': True}, 107),
#  ({'solver': u'BI', 'sparse': False}, 1),
#  ({'solver': u'CS', 'sparse': True}, 232),
#  ({'solver': u'LS', 'sparse': False}, 2962),
#  ({'solver': u'LS', 'sparse': True}, 3929),
#  ({'solver': u'CS', 'sparse': False}, 180)]

# %% [markdown]
# ## [Dense] Plot: grid vs best solver (color); sliced by blocks-to-routes, markers indicate accuracy

# %%
print 'Levels of error: o, ^, v'
print 'LSQR: b, LS: g, CS: r, BI: c'
SS.plot_solver_comparison(sparse=False, caption='', model='P', error_leq=0.1,
                          error_leq2=0.3, error_leq3=10, b2n_leq=1.00, b2n_geq=0.00)
SS.plot_solver_comparison(sparse=False, caption='', model='P', error_leq=0.1,
                          error_leq2=0.3, error_leq3=10, b2n_leq=1.00, b2n_geq=0.95)
SS.plot_solver_comparison(sparse=False, caption='', model='P', error_leq=0.1,
                          error_leq2=0.3, error_leq3=10, b2n_leq=0.95, b2n_geq=0.85)
SS.plot_solver_comparison(sparse=False, caption='', model='P', error_leq=0.1,
                          error_leq2=0.3, error_leq3=10, b2n_leq=0.85, b2n_geq=0.00)
# Out:
# Levels of error: o, ^, v
# LSQR: b, LS: g, CS: r, BI: c

# %% [markdown]
# ## [Sparse] Plot: grid vs best solver (color); sliced by blocks-to-routes, markers indicate accuracy

# %%
SS.plot_solver_comparison(sparse=True, caption='', model='P', error_leq=0.1,
                          error_leq2=0.3, error_leq3=10, b2n_leq=1.00, b2n_geq=0.00)
SS.plot_solver_comparison(sparse=True, caption='', model='P', error_leq=0.1,
                          error_leq2=0.3, error_leq3=10, b2n_leq=1.00, b2n_geq=0.95)
SS.plot_solver_comparison(sparse=True, caption='', model='P', error_leq=0.1,
                          error_leq2=0.3, error_leq3=10, b2n_leq=0.95, b2n_geq=0.85)
SS.plot_solver_comparison(sparse=True, caption='', model='P', error_leq=0.1,
                          error_leq2=0.3, error_leq3=10, b2n_leq=0.85, b2n_geq=0.00)

# %% [markdown]
# # Plot: network size (number of routes) vs speed (seconds)

# %%
SS.plot_size_vs_speed(error_leq=0.10,ylim=(-0.1,2))
SS.plot_size_vs_speed(error_leq=0.20,ylim=(-0.1,5))
SS.plot_size_vs_speed(error_leq=0.30,ylim=(-0.1,5))
SS.plot_size_vs_speed(error_leq=0.50,ylim=(-0.1,10))
SS.plot_size_vs_speed(error_leq=1.00,ylim=(-0.05,10))
# Out:
# [LS (*): 1820]
#  [BI (d): 3]
# [CS (x): 4]
# [LS (*): 2493]
#  [BI (d): 5]
# [CS (x): 4]
# [LS (*): 2894]
#  [BI (d): 5]
# [CS (x): 4]
# [LS (*): 3555]
#  [BI (d): 6]
# [CS (x): 7]
# [LS (*): 4326]
#  [BI (d): 13]
# [CS (x): 369]

# %% [markdown]
# # Plot: sparsity (nonzero routes / number of routes) vs route flow error (%)

# %%
SS.plot_sparsity_vs_error(error_leq=0.10,ylim=(-0.01,0.11),xlim=(0,0.7))
SS.plot_sparsity_vs_error(error_leq=1.00,ylim=(-0.01,1.05),xlim=(0,0.6),solvers=('BI',))
SS.plot_sparsity_vs_error(error_leq=1.00,ylim=(-0.01,1.05),xlim=(0,0.6),solvers=('CS',))
SS.plot_sparsity_vs_error(error_leq=1.00,ylim=(-0.01,1.05),xlim=(0,0.7),solvers=('LS',))
SS.plot_sparsity_vs_error(error_leq=1.00,ylim=(-0.01,1.05),xlim=(0,0.7),solvers=('LSQR',))
# Out:
# [LS (*): 1820]
#  [BI (d): 3]
# [CS (x): 4]
# [BI (*): 13]
# [CS (*): 369]
# [LS (*): 4326]
